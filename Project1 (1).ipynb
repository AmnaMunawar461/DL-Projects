# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('/content/sample_data/Project1-DataSet-Pakistan Largest Ecommerce Dataset.csv')
data1=pd.read_csv('/content/sample_data/Project1-DataSet-Pakistan Largest Ecommerce Dataset.csv')
data

# %% [markdown]
# Visualize payment method and order status frequency

# %%
import pandas
from collections import Counter
letter_counts = Counter(data1['status'])
df = pandas.DataFrame.from_dict(letter_counts, orient='index')
df.plot(kind='bar')

# %%
import pandas
from collections import Counter
letter_counts = Counter(data1['payment_method'])
df = pandas.DataFrame.from_dict(letter_counts, orient='index')
df.plot(kind='bar',color='purple')

# %% [markdown]
# Find a correlation between payment method and order status

# %%
data['status']=data['status'].astype('category').cat.codes
data['payment_method']=data['payment_method'].astype('category').cat.codes
data['status'].corr(data['payment_method'])
# Out:
# 0.12193543228637031

# %% [markdown]
# payment method and order status are weak positive related.

# %% [markdown]
# Find a correlation between order date and item category

# %%
data.columns

data['created_at']=data['created_at'].astype('category').cat.codes
data['category_name_1']=data['category_name_1'].astype('category').cat.codes
data['created_at'].corr(data['category_name_1'])
# Out:
# 0.07546070257412853

# %% [markdown]
# category_name_1 and created_at are having weak positive relationship

# %% [markdown]
# Discover hidden patterns for layman

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
data.plot(x='qty_ordered',y='price',color='red')

# %%
data.plot(x="category_name_1", y="Year", kind="scatter")

# %%
df = pd.DataFrame(data, columns = ['sku', 'price',  
                                    'qty_ordered', 'grand_total', 
                                    'increment_id', 'category_name_1','sales commission_code','Year'] )
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f102cf37d10>,
# ...
#       dtype=object)

# %% [markdown]
# Can we predict future values ?
#
# Yes ,we can predict future values by  using regression model.

# %% [markdown]
# Overall in Project 1,we found if it was possible to predict  future orders ,their quantity.And we discover hidden patterns for layman.We visualize payment method and order status frequency.We found a relation between order date and item category.And we found relation between payment method and order status
